# %% [markdown]
# GENERATE TIME SERIES DATA TO TRANSFER LEARNING(fraction of data )Rate=0.02

# %%
import pandas as pd

dta = {'current': [0,0,0,33,33,33,33,757,757,155,155,155],
                'speed': [3.6,3.6,3.6,3.5,3.6,3.6,3.6,5.4,5.4,5.4,7.2,7.2],
                'jerking': [5.3,5.3,5.3,5.3,5.4,5.6,5.5,5.5,5.5,5.6,5.7,5.9],
                'load': [1464,1394,1357,1293,1256,1254,1234,1195,1159,1167,1130,1134]        
                }

df = pd.DataFrame(dta,columns=['current','speed','jerking','load']) 

print (df)
# Out:
#     current  speed  jerking  load
# 0         0    3.6      5.3  1464
# 1         0    3.6      5.3  1394
# 2         0    3.6      5.3  1357
# 3        33    3.5      5.3  1293
# 4        33    3.6      5.4  1256
# 5        33    3.6      5.6  1254
# 6        33    3.6      5.5  1234
# 7       757    5.4      5.5  1195
# 8       757    5.4      5.5  1159
# 9       155    5.4      5.6  1167
# 10      155    7.2      5.7  1130
# 11      155    7.2      5.9  1134

# %%
import pandas as pd
import matplotlib.pyplot as plt
  

dta = {         'current': [0,0,0,33,33,33,33,757,757,155,155,155],
                'speed': [3.6,3.6,3.6,3.5,3.6,3.6,3.6,5.4,5.4,5.4,7.2,7.2],
                'jerking': [5.3,5.3,5.3,5.3,5.4,5.6,5.5,5.5,5.5,5.6,5.7,5.9],
                'load': [1464,1394,1357,1293,1256,1254,1234,1195,1159,1167,1130,1134]        
                }

df = pd.DataFrame(dta,columns=['current','speed','jerking','load']) 
plt.scatter(df['jerking'], df['load'], color='red')
plt.title('Load Vs Jerking', fontsize=14)
plt.xlabel('Jerking', fontsize=14)
plt.ylabel('Load', fontsize=14)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
  
dta = {         'current': [0,0,0,33,33,33,33,757,757,155,155,155],
                'speed': [3.6,3.6,3.6,3.5,3.6,3.6,3.6,5.4,5.4,5.4,7.2,7.2],
                'jerking': [5.3,5.3,5.3,5.3,5.4,5.6,5.5,5.5,5.5,5.6,5.7,5.9],
                'load': [1464,1394,1357,1293,1256,1254,1234,1195,1159,1167,1130,1134]        
                }

df = pd.DataFrame(dta,columns=['current','speed','jerking','load'])
plt.scatter(df['current'], df['load'], color='green')
plt.title('Load Vs Current', fontsize=14)
plt.xlabel('Current', fontsize=14)
plt.ylabel('Load', fontsize=14)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
  
dta = {         'current': [0,0,0,33,33,33,33,757,757,155,155,155],
                'speed': [3.6,3.6,3.6,3.5,3.6,3.6,3.6,5.4,5.4,5.4,7.2,7.2],
                'jerking': [5.3,5.3,5.3,5.3,5.4,5.6,5.5,5.5,5.5,5.6,5.7,5.9],
                'load': [1464,1394,1357,1293,1256,1254,1234,1195,1159,1167,1130,1134]        
                }

df = pd.DataFrame(dta,columns=['current','speed','jerking','load'])
plt.scatter(df['speed'], df['load'], color='green')
plt.title('Load Vs Speed', fontsize=14)
plt.xlabel('Speed', fontsize=14)
plt.ylabel('Load', fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# (SUMMARY USING)USE THE TRANSFER PLOTTING TO SKLEARN TO CELL STATE 1..
# using the transfer remember sice speed is the parameter that is can be evaluated by general statistics so i am maping it with distance-time series in below Lstm cells.

# %%
import pandas as pd
from sklearn import linear_model
import statsmodels.api as sm

dta = {         'current': [0,0,0,33,33,33,33,757,757,155,155,155],
                'speed': [3.6,3.6,3.6,3.5,3.6,3.6,3.6,5.4,5.4,5.4,7.2,7.2],
                'jerking': [5.3,5.3,5.3,5.3,5.4,5.6,5.5,5.5,5.5,5.6,5.7,5.9],
                'load': [1464,1394,1357,1293,1256,1254,1234,1195,1159,1167,1130,1134]        
                }

df = pd.DataFrame(dta,columns=['current','speed','jerking','load'])

X = df[['jerking','current']] # here we have 2 variables for multiple regression. If you just want to use one variable for simple linear regression, then use X = df['Interest_Rate'] for example.Alternatively, you may add additional variables within the brackets
Y = df['load']
 
# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

# prediction with sklearn
newjerking = 2.75
newcurrent = 5.3

print ('Predicted Load: \n', regr.predict([[newjerking ,newcurrent]]))

# with statsmodels
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
# Intercept:
#  3591.9937686331386
# Coefficients:
#  [-4.21578295e+02 -1.34967127e-01]
# Predicted Load:
#  [2431.93813256]
#                             OLS Regression Results
# ...
# Dep. Variable:                   load   R-squared:                       0.779
# Model:                            OLS   Adj. R-squared:                  0.730
# Method:                 Least Squares   F-statistic:                     15.90
# Date:                Sun, 02 Aug 2020   Prob (F-statistic):            0.00111
# Time:                        15:15:02   Log-Likelihood:                -63.516
# No. Observations:                  12   AIC:                             133.0
# Df Residuals:                       9   BIC:                             134.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
import pandas as pd
from sklearn import linear_model
import tkinter as tk 
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

dta = {         'current': [0,0,0,33,33,33,33,757,757,155,155,155],
                'speed': [3.6,3.6,3.6,3.5,3.6,3.6,3.6,5.4,5.4,5.4,7.2,7.2],
                'jerking': [5.3,5.3,5.3,5.3,5.4,5.6,5.5,5.5,5.5,5.6,5.7,5.9],
                'load': [1464,1394,1357,1293,1256,1254,1234,1195,1159,1167,1130,1134]        
                }

df = pd.DataFrame(dta,columns=['current','speed','jerking','load'])

X = df[['jerking','current']].astype(float) # here we have 2 input variables for multiple regression. If you just want to use one variable for simple linear regression, then use X = df['Interest_Rate'] for example.Alternatively, you may add additional variables within the brackets
Y = df['load'].astype(float) # output variable (what we are trying to predict)

# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

# tkinter GUI
root= tk.Tk()

canvas1 = tk.Canvas(root, width = 500, height = 300)
canvas1.pack()

# with sklearn
Intercept_result = ('Intercept: ', regr.intercept_)
label_Intercept = tk.Label(root, text=Intercept_result, justify = 'center')
canvas1.create_window(260, 220, window=label_Intercept)

# with sklearn
Coefficients_result  = ('Coefficients: ', regr.coef_)
label_Coefficients = tk.Label(root, text=Coefficients_result, justify = 'center')
canvas1.create_window(260, 240, window=label_Coefficients)


label1 = tk.Label(root, text='Value of Jerking: ')
canvas1.create_window(100, 100, window=label1)

entry1 = tk.Entry (root) # create 1st entry box
canvas1.create_window(270, 100, window=entry1)


label2 = tk.Label(root, text='Value of Current: ')
canvas1.create_window(120, 120, window=label2)

entry2 = tk.Entry (root) # create 2nd entry box
canvas1.create_window(270, 120, window=entry2)









def values(): 
    global newjerking #our 1st input variable
    newjerking = float(entry1.get()) 
    
    global newcurrent #our 2nd input variable
    newcurrent = float(entry2.get()) 
    
  
    
   
    Prediction_result  = ('Predicted Load: ', regr.predict([[newjerking ,newcurrent]]))
    label_Prediction = tk.Label(root, text= Prediction_result, bg='orange')
    canvas1.create_window(260, 280, window=label_Prediction)
    
button1 = tk.Button (root, text='Predict Load',command=values, bg='orange') # button to call the 'values' command above 
canvas1.create_window(270, 150, window=button1)
 
#plot 1st scatter 
figure3 = plt.Figure(figsize=(5,4), dpi=100)
ax3 = figure3.add_subplot(111)
ax3.scatter(df['jerking'].astype(float),df['load'].astype(float), color = 'r')
scatter3 = FigureCanvasTkAgg(figure3, root) 
scatter3.get_tk_widget().pack(side=tk.RIGHT, fill=tk.BOTH)
ax3.legend(['load']) 
ax3.set_xlabel('Jerking')
ax3.set_title('Jerking Vs. Load')

#plot 2nd scatter 
figure4 = plt.Figure(figsize=(5,4), dpi=100)
ax4 = figure4.add_subplot(111)
ax4.scatter(df['current'].astype(float),df['load'].astype(float), color = 'b')
scatter4 = FigureCanvasTkAgg(figure4, root) 
scatter4.get_tk_widget().pack(side=tk.RIGHT, fill=tk.BOTH)
ax4.legend(['load']) 
ax4.set_xlabel('Current')
ax4.set_title('Current Vs. Load')



figure5 = plt.Figure(figsize=(5,4), dpi=100)
ax5 = figure5.add_subplot(111)
ax5.scatter(df['speed'].astype(float),df['load'].astype(float), color = 'g')
scatter4 = FigureCanvasTkAgg(figure5, root) 
scatter4.get_tk_widget().pack(side=tk.RIGHT, fill=tk.BOTH)
ax5.legend(['load']) 
ax5.set_xlabel('Speed')
ax5.set_title('Speed Vs. Load')



root.mainloop()
# Out:
# Intercept:
#  3591.9937686331386
# Coefficients:
#  [-4.21578295e+02 -1.34967127e-01]

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix,accuracy_score

from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Activation
from keras.callbacks import EarlyStopping

import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %%
dataset_train=pd.read_csv('input/PM_train.txt',sep=' ',header=None).drop([8,9],axis=1)
col_names = ['id','cycle','normjerk','normx','level','distance','temp','curr_2x','accz']
dataset_train.columns=col_names
print('Shape of Train dataset: ',dataset_train.shape)
dataset_train.head()
# Out:
# Shape of Train dataset:  (367, 9)
#    id  cycle  normjerk   normx  level  distance    temp  curr_2x  accz
# 0   1      1   -0.0007 -0.0004  100.0    518.67  641.82  1589.70   NaN
# 1   1      2    0.0019 -0.0003  100.0    518.67  642.15  1591.82   NaN
# 2   1      3   -0.0043  0.0003  100.0    518.67  642.35  1587.99   NaN
# 3   1      4    0.0007  0.0000  100.0    518.67  642.35  1582.79   NaN
# 4   1      5   -0.0019 -0.0002  100.0    518.67  642.37  1582.85   NaN

# %%
dataset_test=pd.read_csv('input/PM_test.txt',sep=' ',header=None).drop([8,9],axis=1)
col_names = ['id','cycle','normjerk','normx','level','distance','temp','curr_2x']
dataset_test.columns=col_names
#dataset_test.head()
print('Shape of Test dataset: ',dataset_train.shape)
dataset_train.head()
# Out:
# Shape of Test dataset:  (367, 9)
#    id  cycle  normjerk   normx  level  distance    temp  curr_2x  accz
# 0   1      1   -0.0007 -0.0004  100.0    518.67  641.82  1589.70   NaN
# 1   1      2    0.0019 -0.0003  100.0    518.67  642.15  1591.82   NaN
# 2   1      3   -0.0043  0.0003  100.0    518.67  642.35  1587.99   NaN
# 3   1      4    0.0007  0.0000  100.0    518.67  642.35  1582.79   NaN
# 4   1      5   -0.0019 -0.0002  100.0    518.67  642.37  1582.85   NaN

# %%
pm_truth=pd.read_csv('input/PM_truth.txt',sep=' ',header=None).drop([1],axis=1)
pm_truth.columns=['more']
pm_truth['id']=pm_truth.index+1
pm_truth.head()
# Out:
#    more  id
# 0   112   1
# 1    98   2
# 2    69   3
# 3    82   4
# 4    91   5

# %%
# generate column max for test data
rul = pd.DataFrame(dataset_test.groupby('id')['cycle'].max()).reset_index()
rul.columns = ['id', 'max']
rul.head()
# Out:
#    id  max
# 0   1   31
# 1   2   49
# 2   3  126
# 3   4  106
# 4   5   55

# %%
# run to failure
pm_truth['rtf']=pm_truth['more']+rul['max']
pm_truth.head()
# Out:
#    more  id    rtf
# 0   112   1  143.0
# 1    98   2  147.0
# 2    69   3  195.0
# 3    82   4  188.0
# 4    91   5  146.0

# %%
pm_truth.drop('more', axis=1, inplace=True)
dataset_test=dataset_test.merge(pm_truth,on=['id'],how='left')
dataset_test['ttf']=dataset_test['rtf'] - dataset_test['cycle']
dataset_test.drop('rtf', axis=1, inplace=True)
dataset_test.head()
# Out:
#    id  cycle  normjerk   normx  level  distance    temp  curr_2x    ttf
# 0   1      1    0.0023  0.0003  100.0    518.67  643.02  1585.29  142.0
# 1   1      2   -0.0027 -0.0003  100.0    518.67  641.71  1588.45  141.0
# 2   1      3    0.0003  0.0001  100.0    518.67  642.46  1586.94  140.0
# 3   1      4    0.0042  0.0000  100.0    518.67  642.44  1584.12  139.0
# 4   1      5    0.0014  0.0000  100.0    518.67  642.51  1587.19  138.0

# %%
dataset_train['ttf'] = dataset_train.groupby(['id'])['cycle'].transform(max)-dataset_train['cycle']
dataset_train.head()
# Out:
#    id  cycle  normjerk   normx  level  distance    temp  curr_2x  accz  ttf
# 0   1      1   -0.0007 -0.0004  100.0    518.67  641.82  1589.70   NaN  191
# 1   1      2    0.0019 -0.0003  100.0    518.67  642.15  1591.82   NaN  190
# 2   1      3   -0.0043  0.0003  100.0    518.67  642.35  1587.99   NaN  189
# 3   1      4    0.0007  0.0000  100.0    518.67  642.35  1582.79   NaN  188
# 4   1      5   -0.0019 -0.0002  100.0    518.67  642.37  1582.85   NaN  187

# %%
df_train=dataset_train.copy()
df_test=dataset_test.copy()
period=365
df_train['label_bc'] = df_train['ttf'].apply(lambda x: 1 if x <= period else 0)
df_test['label_bc'] = df_test['ttf'].apply(lambda x: 1 if x <= period else 0)
df_train.head()
# Out:
#    id  cycle  normjerk   normx  level  distance    temp  curr_2x  accz  ttf  \
# 0   1      1   -0.0007 -0.0004  100.0    518.67  641.82  1589.70   NaN  191
# 1   1      2    0.0019 -0.0003  100.0    518.67  642.15  1591.82   NaN  190
# 2   1      3   -0.0043  0.0003  100.0    518.67  642.35  1587.99   NaN  189
# 3   1      4    0.0007  0.0000  100.0    518.67  642.35  1582.79   NaN  188
# 4   1      5   -0.0019 -0.0002  100.0    518.67  642.37  1582.85   NaN  187
#
#    label_bc
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1

# %%
features_col_name=['normjerk','normx','level','distance','temp','curr_2x']
target_col_name='label_bc'

# %%
sc=MinMaxScaler()
df_train[features_col_name]=sc.fit_transform(df_train[features_col_name])
df_test[features_col_name]=sc.transform(df_test[features_col_name])

# %%
def gen_sequence(id_df, seq_length, seq_cols):
    df_zeros=pd.DataFrame(np.zeros((seq_length-1,id_df.shape[1])),columns=id_df.columns)
    id_df=df_zeros.append(id_df,ignore_index=True)
    data_array = id_df[seq_cols].values
    num_elements = data_array.shape[0]
    lstm_array=[]
    for start, stop in zip(range(0, num_elements-seq_length), range(seq_length, num_elements)):
        lstm_array.append(data_array[start:stop, :])
    return np.array(lstm_array)

# function to generate labels
def gen_label(id_df, seq_length, seq_cols,label):
    df_zeros=pd.DataFrame(np.zeros((seq_length-1,id_df.shape[1])),columns=id_df.columns)
    id_df=df_zeros.append(id_df,ignore_index=True)
    data_array = id_df[seq_cols].values
    num_elements = data_array.shape[0]
    y_label=[]
    for start, stop in zip(range(0, num_elements-seq_length), range(seq_length, num_elements)):
        y_label.append(id_df[label][stop])
    return np.array(y_label)

# %%
# timestamp or window size
seq_length=50
seq_cols=features_col_name

# %%
# generate X_train
X_train=np.concatenate(list(list(gen_sequence(df_train[df_train['id']==id], seq_length, seq_cols)) for id in df_train['id'].unique()))
print(X_train.shape)
# generate y_train
y_train=np.concatenate(list(list(gen_label(df_train[df_train['id']==id], 50, seq_cols,'label_bc')) for id in df_train['id'].unique()))
print(y_train.shape)
# Out:
# (365, 50, 6)
# (365,)

# %%
# generate X_test
X_test=np.concatenate(list(list(gen_sequence(df_test[df_test['id']==id], seq_length, seq_cols)) for id in df_test['id'].unique()))
print(X_test.shape)
# generate y_test
y_test=np.concatenate(list(list(gen_label(df_test[df_test['id']==id], 50, seq_cols,'label_bc')) for id in df_test['id'].unique()))
print(y_test.shape)
# Out:
# (362, 50, 6)
# (362,)

# %%
nb_features =X_train.shape[2]
timestamp=seq_length

model = Sequential()

model.add(LSTM(
         input_shape=(timestamp, nb_features),
         units=10,
         return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(
          units=50,
          return_sequences=False))
model.add(Dropout(0.2))

model.add(Dense(units=1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_7 (LSTM)                (None, 50, 10)            680
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 50, 10)            0
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 50)                12200
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 51
# ...
# Total params: 12,931
# Trainable params: 12,931
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit the network
model.fit(X_train, y_train, epochs=100, batch_size=200, validation_split=0.05, verbose=1,
          callbacks = [EarlyStopping(monitor='val_loss', min_delta=0, patience=0, verbose=0, mode='auto')])
# Out:
# Train on 346 samples, validate on 19 samples
# Epoch 1/100
# 346/346 [==============================] - 0s 649us/step - loss: 0.2826 - acc: 1.0000 - val_loss: 0.1921 - val_acc: 1.0000
# Epoch 2/100
# 346/346 [==============================] - 0s 669us/step - loss: 0.1933 - acc: 1.0000 - val_loss: 0.1027 - val_acc: 1.0000
# Epoch 3/100
# 346/346 [==============================] - 0s 663us/step - loss: 0.1068 - acc: 1.0000 - val_loss: 0.0501 - val_acc: 1.0000
# Epoch 4/100
# 346/346 [==============================] - 0s 643us/step - loss: 0.0569 - acc: 1.0000 - val_loss: 0.0285 - val_acc: 1.0000
# Epoch 5/100
# 346/346 [==============================] - 0s 643us/step - loss: 0.0313 - acc: 1.0000 - val_loss: 0.0192 - val_acc: 1.0000
# Epoch 6/100
# 346/346 [==============================] - 0s 666us/step - loss: 0.0195 - acc: 1.0000 - val_loss: 0.0141 - val_acc: 1.0000
# Epoch 7/100
# ...

# %%
# training metrics
scores = model.evaluate(X_train, y_train, verbose=1, batch_size=200)
print('Accurracy: {}'.format(scores[0]))
# Out:
# 365/365 [==============================] - 0s 145us/step
# Accurracy: 0.00018439859918108184

# %%
y_pred=model.predict_classes(X_test)
print('Accuracy of model on test data: ',accuracy_score(y_test,y_pred))
print('Confusion Matrix: \n',confusion_matrix(y_test,y_pred))
# Out:
# Accuracy of model on test data:  1.0
# Confusion Matrix:
#  [[362]]

# %%
def prob_failure(machine_id):
    machine_df=df_test[df_test.id==machine_id]
    machine_test=gen_sequence(machine_df,seq_length,seq_cols)
    m_pred=model.predict(machine_test)
    failure_prob=list(m_pred[1]*0.02)[0]
    return failure_prob

# %%
machine_id=5
print('Probability that machine will fail within 365 days: ',prob_failure(machine_id))
# Out:
# Probability that machine will fail within 365 days:  0.019996222

# %%
##here time-series layers from activation function must be added.

# %%
import sys
import PySimpleGUI as sg


def sih2020():
    sg.set_options(text_justification='right')

    flags = [[sg.CB('Normalize', size=(12, 1), default=True), sg.CB('Verbose', size=(20, 1))],
             [sg.CB('Cluster', size=(12, 1)), sg.CB(
                 'Flush Output', size=(20, 1), default=True)],
             [sg.CB('Write Results', size=(12, 1)), sg.CB(
                 'Keep Intermediate Data', size=(20, 1))],
             [sg.CB('Normalize', size=(12, 1), default=True),
              sg.CB('Verbose', size=(20, 1))],
             [sg.CB('Cluster', size=(12, 1)), sg.CB(
                 'Flush Output', size=(20, 1), default=True)],
             [sg.CB('Write Results', size=(12, 1)), sg.CB('Keep Intermediate Data', size=(20, 1))], ]

    loss_functions = [[sg.Rad('Cross-Entropy', 'loss', size=(12, 1)), sg.Rad('Logistic', 'loss', default=True, size=(12, 1))],
                      [sg.Rad('Hinge', 'loss', size=(12, 1)),
                       sg.Rad('Huber', 'loss', size=(12, 1))],
                      [sg.Rad('Kullerback', 'loss', size=(12, 1)),
                       sg.Rad('MAE(L1)', 'loss', size=(12, 1))],
                      [sg.Rad('MSE(L2)', 'loss', size=(12, 1)), sg.Rad('MB(L0)', 'loss', size=(12, 1))], ]

    command_line_parms = [[sg.Text('Passes', size=(8, 1)), sg.Spin(values=[i for i in range(1, 1000)], initial_value=20, size=(6, 1)),
                           sg.Text('Steps', size=(8, 1), pad=((7, 3))), sg.Spin(values=[i for i in range(1, 1000)], initial_value=20, size=(6, 1))],
                          [sg.Text('Rate', size=(8, 1)), sg.Input(default_text='6', size=(8, 1)), sg.Text('nn', size=(8, 1)),
                           sg.Input(default_text='10', size=(10, 1))],
                          [sg.Text('Loss', size=(8, 1)), sg.Input(default_text='ff', size=(8, 1)), sg.Text('ngram', size=(8, 1)),
                           sg.Input(default_text='5', size=(10, 1))],
                          [sg.Text('Updategate', size=(8, 1)), sg.Input(default_text='0.4', size=(8, 1)), sg.Text('Layers', size=(8, 1)),
                           sg.Drop(values=('BatchNorm', 'other'))], ]

    layout = [[sg.Frame('Command Line Parameteres', command_line_parms, title_color='green', font='Any 12')],
              [sg.Frame('Flags', flags, font='Any 12', title_color='blue')],
              [sg.Frame('Loss Functions',  loss_functions,
                        font='Any 12', title_color='red')],
              [sg.Submit(), sg.Cancel()]]

    sg.set_options(text_justification='left')

    window = sg.Window('SIH 2020 Front End',
                       layout, font=("Helvetica", 12))
    button, values = window.read()
    window.close()
    print(button, values)


def CustomMeter():
    # layout the form
    layout = [[sg.Text('Loading the layers with 5 parameters')],
              [sg.ProgressBar(1000, orientation='h',
                              size=(20, 20), key='progress')],
              [sg.Cancel()]]

    # create the form`
    window = sg.Window('progress', layout)
    progress_bar = window['progress']
    # loop that would normally do something useful
    for i in range(1000):
        # check to see if the cancel button was clicked and exit loop if clicked
        event, values = window.read(timeout=0, timeout_key='timeout')
        if event == 'Cancel' or event == None:
            break
        # update bar with loop value +1 so that bar eventually reaches the maximum
        progress_bar.update_bar(i+1)
    # done with loop... need to destroy the window as it's still open
    window.CloseNonBlocking()


if __name__ == '__main__':
    CustomMeter()
    sih2020()
    
import PySimpleGUI as sg

layout = [[sg.Text("Normal Condition")], [sg.Button("OK")]]

# Create the window
window = sg.Window("Demo", layout)

# Create an event loop
while True:
    event, values = window.read()
    # End program if user closes window or
    # presses the OK button
    if event == "OK" or event == sg.WIN_CLOSED:
        break

window.close()
# Out:
# None {0: None, 1: None, 2: None, 3: None, 4: None, 5: None, 6: None, 7: None, 8: None, 9: None, 10: None, 11: None, 12: None, 13: None, 14: None, 15: None, 16: None, 17: None, 18: None, 19: None, 20: None, 21: None, 22: None, 23: None, 24: None, 25: None, 26: None, 27: None}
